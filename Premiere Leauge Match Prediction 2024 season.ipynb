# %%
import pandas as pd
import numpy as np
import pickle
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
import sklearn

# %%
print("pandas", pd.__version__)
print("numpy", np.__version__)
print("sklearn", sklearn.__version__)
# Out:
# pandas 1.5.3
# numpy 1.24.3
# sklearn 1.2.2

# %%
matches = pd.read_csv("matches.csv", index_col = 0)

# %%
matches.head()
# Out:
#          Date   Time            Comp        Round  Day Venue Result  GF  GA  \
# 1  2023-08-11  20:00  Premier League  Matchweek 1  Fri  Away      W   3   0
# 3  2023-08-19  20:00  Premier League  Matchweek 2  Sat  Home      W   1   0
# 4  2023-08-27  14:00  Premier League  Matchweek 3  Sun  Away      W   2   1
# 5  2023-09-02  15:00  Premier League  Matchweek 4  Sat  Home      W   5   1
# 6  2023-09-16  15:00  Premier League  Matchweek 5  Sat  Away      W   3   1
#
#         Opponent  ...  Match Report  Notes    Sh   SoT  Dist   FK PK PKatt  \
# 1        Burnley  ...  Match Report    NaN  17.0   8.0  13.9  0.0  0     0
# 3  Newcastle Utd  ...  Match Report    NaN  14.0   4.0  17.9  0.0  0     0
# 4  Sheffield Utd  ...  Match Report    NaN  29.0   9.0  17.3  2.0  0     1
# 5         Fulham  ...  Match Report    NaN   6.0   4.0  14.8  0.0  1     1
# 6       West Ham  ...  Match Report    NaN  29.0  13.0  16.4  1.0  0     0
#
#    Season            Team
# 1    2024  ManchesterCity
# 3    2024  ManchesterCity
# 4    2024  ManchesterCity
# 5    2024  ManchesterCity
# 6    2024  ManchesterCity
#
# [5 rows x 27 columns]

# %%
matches.shape
# Out:
# (760, 27)

# %%
38 * 20 * 2
# Out:
# 1520

# %%
matches["Team"].value_counts()
# Out:
# ManchesterCity            38
# Arsenal                   38
# Burnley                   38
# LutonTown                 38
# NottinghamForest          38
# Brentford                 38
# Everton                   38
# WolverhamptonWanderers    38
# Fulham                    38
# Bournemouth               38
# BrightonandHoveAlbion     38
# CrystalPalace             38
# WestHamUnited             38
# ManchesterUnited          38
# NewcastleUnited           38
# Chelsea                   38
# TottenhamHotspur          38
# AstonVilla                38
# Liverpool                 38
# SheffieldUnited           38
# Name: Team, dtype: int64

# %%
matches[matches["Team"] == "ManchesterCity"]
# Out:
#           Date   Time            Comp         Round  Day Venue Result  GF  GA  \
# 1   2023-08-11  20:00  Premier League   Matchweek 1  Fri  Away      W   3   0
# 3   2023-08-19  20:00  Premier League   Matchweek 2  Sat  Home      W   1   0
# 4   2023-08-27  14:00  Premier League   Matchweek 3  Sun  Away      W   2   1
# 5   2023-09-02  15:00  Premier League   Matchweek 4  Sat  Home      W   5   1
# 6   2023-09-16  15:00  Premier League   Matchweek 5  Sat  Away      W   3   1
# 8   2023-09-23  15:00  Premier League   Matchweek 6  Sat  Home      W   2   0
# 10  2023-09-30  15:00  Premier League   Matchweek 7  Sat  Away      L   1   2
# 12  2023-10-08  16:30  Premier League   Matchweek 8  Sun  Away      L   0   1
# 13  2023-10-21  15:00  Premier League   Matchweek 9  Sat  Home      W   2   1
# 15  2023-10-29  15:30  Premier League  Matchweek 10  Sun  Away      W   3   0
# 16  2023-11-04  15:00  Premier League  Matchweek 11  Sat  Home      W   6   1
# 18  2023-11-12  16:30  Premier League  Matchweek 12  Sun  Away      D   4   4
# 19  2023-11-25  12:30  Premier League  Matchweek 13  Sat  Home      D   1   1
# 21  2023-12-03  16:30  Premier League  Matchweek 14  Sun  Home      D   3   3
# 22  2023-12-06  20:15  Premier League  Matchweek 15  Wed  Away      L   0   1
# 23  2023-12-10  14:00  Premier League  Matchweek 16  Sun  Away      W   2   1
# 25  2023-12-16  15:00  Premier League  Matchweek 17  Sat  Home      D   2   2
# 26  2023-12-27  20:15  Premier League  Matchweek 19  Wed  Away      W   3   1
# 27  2023-12-30  15:00  Premier League  Matchweek 20  Sat  Home      W   2   0
# 29  2024-01-13  17:30  Premier League  Matchweek 21  Sat  Away      W   3   2
# 31  2024-01-31  19:30  Premier League  Matchweek 22  Wed  Home      W   3   1
# 32  2024-02-05  20:00  Premier League  Matchweek 23  Mon  Away      W   3   1
# 33  2024-02-10  12:30  Premier League  Matchweek 24  Sat  Home      W   2   0
# 35  2024-02-17  17:30  Premier League  Matchweek 25  Sat  Home      D   1   1
# 36  2024-02-20  19:30  Premier League  Matchweek 18  Tue  Home      W   1   0
# 37  2024-02-24  17:30  Premier League  Matchweek 26  Sat  Away      W   1   0
# 39  2024-03-03  15:30  Premier League  Matchweek 27  Sun  Home      W   3   1
# 41  2024-03-10  15:45  Premier League  Matchweek 28  Sun  Away      D   1   1
# 43  2024-03-31  16:30  Premier League  Matchweek 30  Sun  Home      D   0   0
# 44  2024-04-03  20:15  Premier League  Matchweek 31  Wed  Home      W   4   1
# 45  2024-04-06  12:30  Premier League  Matchweek 32  Sat  Away      W   4   2
# 47  2024-04-13  15:00  Premier League  Matchweek 33  Sat  Home      W   5   1
# 50  2024-04-25  20:00  Premier League  Matchweek 29  Thu  Away      W   4   0
# 51  2024-04-28  16:30  Premier League  Matchweek 35  Sun  Away      W   2   0
# 52  2024-05-04  17:30  Premier League  Matchweek 36  Sat  Home      W   5   1
# 53  2024-05-11  12:30  Premier League  Matchweek 37  Sat  Away      W   4   0
# 54  2024-05-14  20:00  Premier League  Matchweek 34  Tue  Away      W   2   0
# 55  2024-05-19  16:00  Premier League  Matchweek 38  Sun  Home      W   3   1
#
#            Opponent  ...  Match Report  Notes    Sh   SoT  Dist   FK PK PKatt  \
# 1           Burnley  ...  Match Report    NaN  17.0   8.0  13.9  0.0  0     0
# 3     Newcastle Utd  ...  Match Report    NaN  14.0   4.0  17.9  0.0  0     0
# 4     Sheffield Utd  ...  Match Report    NaN  29.0   9.0  17.3  2.0  0     1
# 5            Fulham  ...  Match Report    NaN   6.0   4.0  14.8  0.0  1     1
# 6          West Ham  ...  Match Report    NaN  29.0  13.0  16.4  1.0  0     0
# 8   Nott'ham Forest  ...  Match Report    NaN   7.0   4.0  17.2  2.0  0     0
# 10           Wolves  ...  Match Report    NaN  23.0   8.0  19.3  1.0  0     0
# 12          Arsenal  ...  Match Report    NaN   4.0   0.0  14.9  0.0  0     0
# 13         Brighton  ...  Match Report    NaN  10.0   5.0  18.8  1.0  0     0
# 15   Manchester Utd  ...  Match Report    NaN  20.0   9.0  17.2  2.0  1     1
# 16      Bournemouth  ...  Match Report    NaN  21.0   8.0  16.4  0.0  0     0
# 18          Chelsea  ...  Match Report    NaN  14.0   9.0  16.6  1.0  1     1
# 19        Liverpool  ...  Match Report    NaN  16.0   5.0  16.3  1.0  0     0
# 21        Tottenham  ...  Match Report    NaN  17.0   4.0  13.4  0.0  0     0
# 22      Aston Villa  ...  Match Report    NaN   2.0   2.0   7.4  0.0  0     0
# 23       Luton Town  ...  Match Report    NaN  18.0   6.0  18.7  1.0  0     0
# 25   Crystal Palace  ...  Match Report    NaN  19.0   9.0  18.2  0.0  0     0
# 26          Everton  ...  Match Report    NaN  22.0   8.0  19.5  1.0  1     1
# 27    Sheffield Utd  ...  Match Report    NaN  18.0   4.0  17.4  0.0  0     0
# 29    Newcastle Utd  ...  Match Report    NaN  27.0  11.0  19.3  2.0  0     0
# 31          Burnley  ...  Match Report    NaN  14.0   4.0  15.8  1.0  0     0
# 32        Brentford  ...  Match Report    NaN  25.0  15.0  19.2  0.0  0     0
# 33          Everton  ...  Match Report    NaN  19.0   3.0  17.4  0.0  0     0
# 35          Chelsea  ...  Match Report    NaN  31.0   5.0  15.9  1.0  0     0
# 36        Brentford  ...  Match Report    NaN  25.0  10.0  17.6  0.0  0     0
# 37      Bournemouth  ...  Match Report    NaN  15.0   6.0  15.5  1.0  0     0
# 39   Manchester Utd  ...  Match Report    NaN  27.0   8.0  17.7  1.0  0     0
# 41        Liverpool  ...  Match Report    NaN  10.0   6.0  18.6  0.0  0     0
# 43          Arsenal  ...  Match Report    NaN  12.0   1.0  14.2  0.0  0     0
# 44      Aston Villa  ...  Match Report    NaN  25.0  11.0  15.9  2.0  0     0
# 45   Crystal Palace  ...  Match Report    NaN  18.0   8.0  16.1  0.0  0     0
# 47       Luton Town  ...  Match Report    NaN  36.0  12.0  16.9  0.0  1     1
# 50         Brighton  ...  Match Report    NaN  14.0   6.0  17.0  1.0  0     0
# 51  Nott'ham Forest  ...  Match Report    NaN  11.0   5.0  18.7  1.0  0     0
# 52           Wolves  ...  Match Report    NaN  18.0  10.0  15.3  0.0  2     2
# 53           Fulham  ...  Match Report    NaN  15.0   8.0  17.6  0.0  1     1
# 54        Tottenham  ...  Match Report    NaN   7.0   4.0  14.5  0.0  1     1
# 55         West Ham  ...  Match Report    NaN  28.0  12.0  17.9  2.0  0     0
#
#     Season            Team
# 1     2024  ManchesterCity
# 3     2024  ManchesterCity
# 4     2024  ManchesterCity
# 5     2024  ManchesterCity
# 6     2024  ManchesterCity
# 8     2024  ManchesterCity
# 10    2024  ManchesterCity
# 12    2024  ManchesterCity
# 13    2024  ManchesterCity
# 15    2024  ManchesterCity
# 16    2024  ManchesterCity
# 18    2024  ManchesterCity
# 19    2024  ManchesterCity
# 21    2024  ManchesterCity
# 22    2024  ManchesterCity
# 23    2024  ManchesterCity
# 25    2024  ManchesterCity
# 26    2024  ManchesterCity
# 27    2024  ManchesterCity
# 29    2024  ManchesterCity
# 31    2024  ManchesterCity
# 32    2024  ManchesterCity
# 33    2024  ManchesterCity
# 35    2024  ManchesterCity
# 36    2024  ManchesterCity
# 37    2024  ManchesterCity
# 39    2024  ManchesterCity
# 41    2024  ManchesterCity
# 43    2024  ManchesterCity
# 44    2024  ManchesterCity
# 45    2024  ManchesterCity
# 47    2024  ManchesterCity
# 50    2024  ManchesterCity
# 51    2024  ManchesterCity
# 52    2024  ManchesterCity
# 53    2024  ManchesterCity
# 54    2024  ManchesterCity
# 55    2024  ManchesterCity
#
# [38 rows x 27 columns]

# %%
matches["Round"].value_counts()
# Out:
# Matchweek 1     20
# Matchweek 30    20
# Matchweek 23    20
# Matchweek 24    20
# Matchweek 25    20
# Matchweek 18    20
# Matchweek 26    20
# Matchweek 27    20
# Matchweek 28    20
# Matchweek 31    20
# Matchweek 2     20
# Matchweek 32    20
# Matchweek 33    20
# Matchweek 29    20
# Matchweek 35    20
# Matchweek 36    20
# Matchweek 37    20
# Matchweek 34    20
# Matchweek 22    20
# Matchweek 21    20
# Matchweek 20    20
# Matchweek 19    20
# Matchweek 3     20
# Matchweek 4     20
# Matchweek 5     20
# Matchweek 6     20
# Matchweek 7     20
# Matchweek 8     20
# Matchweek 9     20
# Matchweek 10    20
# Matchweek 11    20
# Matchweek 12    20
# Matchweek 13    20
# Matchweek 14    20
# Matchweek 15    20
# Matchweek 16    20
# Matchweek 17    20
# Matchweek 38    20
# Name: Round, dtype: int64

# %%
matches.dtypes
# Out:
# Date             object
# Time             object
# Comp             object
# Round            object
# Day              object
# Venue            object
# Result           object
# GF                int64
# GA                int64
# Opponent         object
# xG              float64
# xGA             float64
# Poss            float64
# Attendance      float64
# Captain          object
# Formation        object
# Referee          object
# Match Report     object
# Notes           float64
# Sh              float64
# SoT             float64
# Dist            float64
# FK              float64
# PK                int64
# PKatt             int64
# Season            int64
# Team             object
# dtype: object

# %%
matches["Date"] = pd.to_datetime(matches["Date"])
matches
# Out:
#          Date   Time            Comp         Round  Day Venue Result  GF  GA  \
# 1  2023-08-11  20:00  Premier League   Matchweek 1  Fri  Away      W   3   0
# 3  2023-08-19  20:00  Premier League   Matchweek 2  Sat  Home      W   1   0
# 4  2023-08-27  14:00  Premier League   Matchweek 3  Sun  Away      W   2   1
# 5  2023-09-02  15:00  Premier League   Matchweek 4  Sat  Home      W   5   1
# 6  2023-09-16  15:00  Premier League   Matchweek 5  Sat  Away      W   3   1
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 36 2024-04-24  20:00  Premier League  Matchweek 29  Wed  Away      L   2   4
# 37 2024-04-27  15:00  Premier League  Matchweek 35  Sat  Away      L   1   5
# 38 2024-05-04  15:00  Premier League  Matchweek 36  Sat  Home      L   1   3
# 39 2024-05-11  15:00  Premier League  Matchweek 37  Sat  Away      L   0   1
# 40 2024-05-19  16:00  Premier League  Matchweek 38  Sun  Home      L   0   3
#
#            Opponent  ...  Match Report  Notes    Sh   SoT  Dist   FK PK PKatt  \
# 1           Burnley  ...  Match Report    NaN  17.0   8.0  13.9  0.0  0     0
# 3     Newcastle Utd  ...  Match Report    NaN  14.0   4.0  17.9  0.0  0     0
# 4     Sheffield Utd  ...  Match Report    NaN  29.0   9.0  17.3  2.0  0     1
# 5            Fulham  ...  Match Report    NaN   6.0   4.0  14.8  0.0  1     1
# 6          West Ham  ...  Match Report    NaN  29.0  13.0  16.4  1.0  0     0
# ..              ...  ...           ...    ...   ...   ...   ...  ... ..   ...
# 36   Manchester Utd  ...  Match Report    NaN  10.0   4.0  17.8  1.0  0     0
# 37    Newcastle Utd  ...  Match Report    NaN  15.0   4.0  13.5  0.0  0     0
# 38  Nott'ham Forest  ...  Match Report    NaN  16.0   4.0  18.0  0.0  1     1
# 39          Everton  ...  Match Report    NaN  13.0   1.0  21.0  0.0  0     0
# 40        Tottenham  ...  Match Report    NaN   6.0   1.0  18.0  1.0  0     0
#
#     Season             Team
# 1     2024   ManchesterCity
# 3     2024   ManchesterCity
# 4     2024   ManchesterCity
# 5     2024   ManchesterCity
# 6     2024   ManchesterCity
# ..     ...              ...
# 36    2024  SheffieldUnited
# 37    2024  SheffieldUnited
# 38    2024  SheffieldUnited
# 39    2024  SheffieldUnited
# 40    2024  SheffieldUnited
#
# [760 rows x 27 columns]

# %%
matches.dtypes
# Out:
# Date            datetime64[ns]
# Time                    object
# Comp                    object
# Round                   object
# Day                     object
# Venue                   object
# Result                  object
# GF                       int64
# GA                       int64
# Opponent                object
# xG                     float64
# xGA                    float64
# Poss                   float64
# Attendance             float64
# Captain                 object
# Formation               object
# Referee                 object
# Match Report            object
# Notes                  float64
# Sh                     float64
# SoT                    float64
# Dist                   float64
# FK                     float64
# PK                       int64
# PKatt                    int64
# Season                   int64
# Team                    object
# dtype: object

# %% [markdown]
# # Creating Predictors for machine learning

# %%
matches["venue_code"] = matches["Venue"].astype("category").cat.codes

# %%
matches["opp_code"] = matches["Opponent"].astype("category").cat.codes

# %%
matches["hour"] = matches["Time"].str.replace(":.+", "", regex = True).astype("int")

# %%
matches["day_code"] = matches["Date"].dt.dayofweek

# %%
matches["target"] = (matches["Result"] == "W").astype("int")

# %%
matches
# Out:
#          Date   Time            Comp         Round  Day Venue Result  GF  GA  \
# 1  2023-08-11  20:00  Premier League   Matchweek 1  Fri  Away      W   3   0
# 3  2023-08-19  20:00  Premier League   Matchweek 2  Sat  Home      W   1   0
# 4  2023-08-27  14:00  Premier League   Matchweek 3  Sun  Away      W   2   1
# 5  2023-09-02  15:00  Premier League   Matchweek 4  Sat  Home      W   5   1
# 6  2023-09-16  15:00  Premier League   Matchweek 5  Sat  Away      W   3   1
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 36 2024-04-24  20:00  Premier League  Matchweek 29  Wed  Away      L   2   4
# 37 2024-04-27  15:00  Premier League  Matchweek 35  Sat  Away      L   1   5
# 38 2024-05-04  15:00  Premier League  Matchweek 36  Sat  Home      L   1   3
# 39 2024-05-11  15:00  Premier League  Matchweek 37  Sat  Away      L   0   1
# 40 2024-05-19  16:00  Premier League  Matchweek 38  Sun  Home      L   0   3
#
#            Opponent  ...   FK  PK  PKatt  Season             Team venue_code  \
# 1           Burnley  ...  0.0   0      0    2024   ManchesterCity          0
# 3     Newcastle Utd  ...  0.0   0      0    2024   ManchesterCity          1
# 4     Sheffield Utd  ...  2.0   0      1    2024   ManchesterCity          0
# 5            Fulham  ...  0.0   1      1    2024   ManchesterCity          1
# 6          West Ham  ...  1.0   0      0    2024   ManchesterCity          0
# ..              ...  ...  ...  ..    ...     ...              ...        ...
# 36   Manchester Utd  ...  1.0   0      0    2024  SheffieldUnited          0
# 37    Newcastle Utd  ...  0.0   0      0    2024  SheffieldUnited          0
# 38  Nott'ham Forest  ...  0.0   1      1    2024  SheffieldUnited          1
# 39          Everton  ...  0.0   0      0    2024  SheffieldUnited          0
# 40        Tottenham  ...  1.0   0      0    2024  SheffieldUnited          1
#
#    opp_code hour  day_code  target
# 1         5   20         4       1
# 3        14   20         5       1
# 4        16   14         6       1
# 5         9   15         5       1
# 6        18   15         5       1
# ..      ...  ...       ...     ...
# 36       13   20         2       0
# 37       14   15         5       0
# 38       15   15         5       0
# 39        8   15         5       0
# 40       17   16         6       0
#
# [760 rows x 32 columns]

# %% [markdown]
# # Creating our initial machine learning model

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators = 50, min_samples_split = 10, random_state = 1)

# %%
train = matches[matches["Date"] < '2024-01-01']
test = matches[matches["Date"] > '2024-01-01']

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score
acc = accuracy_score(test["target"], preds)

# %%
acc
# Out:
# 0.5956284153005464

# %%
combined = pd.DataFrame(dict(actual = test["target"], prediction = preds))

# %%
pd.crosstab(index = combined["actual"], columns = combined["prediction"])
# Out:
# prediction    0   1
# actual
# 0           168  61
# 1            87  50

# %%
 from sklearn.metrics import precision_score

# %%
precision_score(test["target"], preds)
# Out:
# 0.45045045045045046

# %%
grouped_matches = matches.groupby("Team")

# %%
group = grouped_matches.get_group("ManchesterCity")
group
# Out:
#          Date   Time            Comp         Round  Day Venue Result  GF  GA  \
# 1  2023-08-11  20:00  Premier League   Matchweek 1  Fri  Away      W   3   0
# 3  2023-08-19  20:00  Premier League   Matchweek 2  Sat  Home      W   1   0
# 4  2023-08-27  14:00  Premier League   Matchweek 3  Sun  Away      W   2   1
# 5  2023-09-02  15:00  Premier League   Matchweek 4  Sat  Home      W   5   1
# 6  2023-09-16  15:00  Premier League   Matchweek 5  Sat  Away      W   3   1
# 8  2023-09-23  15:00  Premier League   Matchweek 6  Sat  Home      W   2   0
# 10 2023-09-30  15:00  Premier League   Matchweek 7  Sat  Away      L   1   2
# 12 2023-10-08  16:30  Premier League   Matchweek 8  Sun  Away      L   0   1
# 13 2023-10-21  15:00  Premier League   Matchweek 9  Sat  Home      W   2   1
# 15 2023-10-29  15:30  Premier League  Matchweek 10  Sun  Away      W   3   0
# 16 2023-11-04  15:00  Premier League  Matchweek 11  Sat  Home      W   6   1
# 18 2023-11-12  16:30  Premier League  Matchweek 12  Sun  Away      D   4   4
# 19 2023-11-25  12:30  Premier League  Matchweek 13  Sat  Home      D   1   1
# 21 2023-12-03  16:30  Premier League  Matchweek 14  Sun  Home      D   3   3
# 22 2023-12-06  20:15  Premier League  Matchweek 15  Wed  Away      L   0   1
# 23 2023-12-10  14:00  Premier League  Matchweek 16  Sun  Away      W   2   1
# 25 2023-12-16  15:00  Premier League  Matchweek 17  Sat  Home      D   2   2
# 26 2023-12-27  20:15  Premier League  Matchweek 19  Wed  Away      W   3   1
# 27 2023-12-30  15:00  Premier League  Matchweek 20  Sat  Home      W   2   0
# 29 2024-01-13  17:30  Premier League  Matchweek 21  Sat  Away      W   3   2
# 31 2024-01-31  19:30  Premier League  Matchweek 22  Wed  Home      W   3   1
# 32 2024-02-05  20:00  Premier League  Matchweek 23  Mon  Away      W   3   1
# 33 2024-02-10  12:30  Premier League  Matchweek 24  Sat  Home      W   2   0
# 35 2024-02-17  17:30  Premier League  Matchweek 25  Sat  Home      D   1   1
# 36 2024-02-20  19:30  Premier League  Matchweek 18  Tue  Home      W   1   0
# 37 2024-02-24  17:30  Premier League  Matchweek 26  Sat  Away      W   1   0
# 39 2024-03-03  15:30  Premier League  Matchweek 27  Sun  Home      W   3   1
# 41 2024-03-10  15:45  Premier League  Matchweek 28  Sun  Away      D   1   1
# 43 2024-03-31  16:30  Premier League  Matchweek 30  Sun  Home      D   0   0
# 44 2024-04-03  20:15  Premier League  Matchweek 31  Wed  Home      W   4   1
# 45 2024-04-06  12:30  Premier League  Matchweek 32  Sat  Away      W   4   2
# 47 2024-04-13  15:00  Premier League  Matchweek 33  Sat  Home      W   5   1
# 50 2024-04-25  20:00  Premier League  Matchweek 29  Thu  Away      W   4   0
# 51 2024-04-28  16:30  Premier League  Matchweek 35  Sun  Away      W   2   0
# 52 2024-05-04  17:30  Premier League  Matchweek 36  Sat  Home      W   5   1
# 53 2024-05-11  12:30  Premier League  Matchweek 37  Sat  Away      W   4   0
# 54 2024-05-14  20:00  Premier League  Matchweek 34  Tue  Away      W   2   0
# 55 2024-05-19  16:00  Premier League  Matchweek 38  Sun  Home      W   3   1
#
#            Opponent  ...   FK  PK  PKatt  Season            Team venue_code  \
# 1           Burnley  ...  0.0   0      0    2024  ManchesterCity          0
# 3     Newcastle Utd  ...  0.0   0      0    2024  ManchesterCity          1
# 4     Sheffield Utd  ...  2.0   0      1    2024  ManchesterCity          0
# 5            Fulham  ...  0.0   1      1    2024  ManchesterCity          1
# 6          West Ham  ...  1.0   0      0    2024  ManchesterCity          0
# 8   Nott'ham Forest  ...  2.0   0      0    2024  ManchesterCity          1
# 10           Wolves  ...  1.0   0      0    2024  ManchesterCity          0
# 12          Arsenal  ...  0.0   0      0    2024  ManchesterCity          0
# 13         Brighton  ...  1.0   0      0    2024  ManchesterCity          1
# 15   Manchester Utd  ...  2.0   1      1    2024  ManchesterCity          0
# 16      Bournemouth  ...  0.0   0      0    2024  ManchesterCity          1
# 18          Chelsea  ...  1.0   1      1    2024  ManchesterCity          0
# 19        Liverpool  ...  1.0   0      0    2024  ManchesterCity          1
# 21        Tottenham  ...  0.0   0      0    2024  ManchesterCity          1
# 22      Aston Villa  ...  0.0   0      0    2024  ManchesterCity          0
# 23       Luton Town  ...  1.0   0      0    2024  ManchesterCity          0
# 25   Crystal Palace  ...  0.0   0      0    2024  ManchesterCity          1
# 26          Everton  ...  1.0   1      1    2024  ManchesterCity          0
# 27    Sheffield Utd  ...  0.0   0      0    2024  ManchesterCity          1
# 29    Newcastle Utd  ...  2.0   0      0    2024  ManchesterCity          0
# 31          Burnley  ...  1.0   0      0    2024  ManchesterCity          1
# 32        Brentford  ...  0.0   0      0    2024  ManchesterCity          0
# 33          Everton  ...  0.0   0      0    2024  ManchesterCity          1
# 35          Chelsea  ...  1.0   0      0    2024  ManchesterCity          1
# 36        Brentford  ...  0.0   0      0    2024  ManchesterCity          1
# 37      Bournemouth  ...  1.0   0      0    2024  ManchesterCity          0
# 39   Manchester Utd  ...  1.0   0      0    2024  ManchesterCity          1
# 41        Liverpool  ...  0.0   0      0    2024  ManchesterCity          0
# 43          Arsenal  ...  0.0   0      0    2024  ManchesterCity          1
# 44      Aston Villa  ...  2.0   0      0    2024  ManchesterCity          1
# 45   Crystal Palace  ...  0.0   0      0    2024  ManchesterCity          0
# 47       Luton Town  ...  0.0   1      1    2024  ManchesterCity          1
# 50         Brighton  ...  1.0   0      0    2024  ManchesterCity          0
# 51  Nott'ham Forest  ...  1.0   0      0    2024  ManchesterCity          0
# 52           Wolves  ...  0.0   2      2    2024  ManchesterCity          1
# 53           Fulham  ...  0.0   1      1    2024  ManchesterCity          0
# 54        Tottenham  ...  0.0   1      1    2024  ManchesterCity          0
# 55         West Ham  ...  2.0   0      0    2024  ManchesterCity          1
#
#    opp_code hour  day_code  target
# 1         5   20         4       1
# 3        14   20         5       1
# 4        16   14         6       1
# 5         9   15         5       1
# 6        18   15         5       1
# 8        15   15         5       1
# 10       19   15         5       0
# 12        0   16         6       0
# 13        4   15         5       1
# 15       13   15         6       1
# 16        2   15         5       1
# 18        6   16         6       0
# 19       10   12         5       0
# 21       17   16         6       0
# 22        1   20         2       0
# 23       11   14         6       1
# 25        7   15         5       0
# 26        8   20         2       1
# 27       16   15         5       1
# 29       14   17         5       1
# 31        5   19         2       1
# 32        3   20         0       1
# 33        8   12         5       1
# 35        6   17         5       0
# 36        3   19         1       1
# 37        2   17         5       1
# 39       13   15         6       1
# 41       10   15         6       0
# 43        0   16         6       0
# 44        1   20         2       1
# 45        7   12         5       1
# 47       11   15         5       1
# 50        4   20         3       1
# 51       15   16         6       1
# 52       19   17         5       1
# 53        9   12         5       1
# 54       17   20         1       1
# 55       18   16         6       1
#
# [38 rows x 32 columns]

# %% [markdown]
# # Improving precision with rolling averages

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("Date")
    rolling_stats = group[cols].rolling(3, closed = 'left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset = new_cols)
    return group

# %%
cols = ["GF", "GA", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]
new_cols = [f"{c}_rolling" for c in cols]
new_cols
# Out:
# ['GF_rolling',
#  'GA_rolling',
#  'Sh_rolling',
#  'SoT_rolling',
#  'Dist_rolling',
#  'FK_rolling',
#  'PK_rolling',
#  'PKatt_rolling']

# %%
rolling_averages(group, cols, new_cols)
# Out:
#          Date   Time            Comp         Round  Day Venue Result  GF  GA  \
# 5  2023-09-02  15:00  Premier League   Matchweek 4  Sat  Home      W   5   1
# 6  2023-09-16  15:00  Premier League   Matchweek 5  Sat  Away      W   3   1
# 8  2023-09-23  15:00  Premier League   Matchweek 6  Sat  Home      W   2   0
# 10 2023-09-30  15:00  Premier League   Matchweek 7  Sat  Away      L   1   2
# 12 2023-10-08  16:30  Premier League   Matchweek 8  Sun  Away      L   0   1
# 13 2023-10-21  15:00  Premier League   Matchweek 9  Sat  Home      W   2   1
# 15 2023-10-29  15:30  Premier League  Matchweek 10  Sun  Away      W   3   0
# 16 2023-11-04  15:00  Premier League  Matchweek 11  Sat  Home      W   6   1
# 18 2023-11-12  16:30  Premier League  Matchweek 12  Sun  Away      D   4   4
# 19 2023-11-25  12:30  Premier League  Matchweek 13  Sat  Home      D   1   1
# 21 2023-12-03  16:30  Premier League  Matchweek 14  Sun  Home      D   3   3
# 22 2023-12-06  20:15  Premier League  Matchweek 15  Wed  Away      L   0   1
# 23 2023-12-10  14:00  Premier League  Matchweek 16  Sun  Away      W   2   1
# 25 2023-12-16  15:00  Premier League  Matchweek 17  Sat  Home      D   2   2
# 26 2023-12-27  20:15  Premier League  Matchweek 19  Wed  Away      W   3   1
# 27 2023-12-30  15:00  Premier League  Matchweek 20  Sat  Home      W   2   0
# 29 2024-01-13  17:30  Premier League  Matchweek 21  Sat  Away      W   3   2
# 31 2024-01-31  19:30  Premier League  Matchweek 22  Wed  Home      W   3   1
# 32 2024-02-05  20:00  Premier League  Matchweek 23  Mon  Away      W   3   1
# 33 2024-02-10  12:30  Premier League  Matchweek 24  Sat  Home      W   2   0
# 35 2024-02-17  17:30  Premier League  Matchweek 25  Sat  Home      D   1   1
# 36 2024-02-20  19:30  Premier League  Matchweek 18  Tue  Home      W   1   0
# 37 2024-02-24  17:30  Premier League  Matchweek 26  Sat  Away      W   1   0
# 39 2024-03-03  15:30  Premier League  Matchweek 27  Sun  Home      W   3   1
# 41 2024-03-10  15:45  Premier League  Matchweek 28  Sun  Away      D   1   1
# 43 2024-03-31  16:30  Premier League  Matchweek 30  Sun  Home      D   0   0
# 44 2024-04-03  20:15  Premier League  Matchweek 31  Wed  Home      W   4   1
# 45 2024-04-06  12:30  Premier League  Matchweek 32  Sat  Away      W   4   2
# 47 2024-04-13  15:00  Premier League  Matchweek 33  Sat  Home      W   5   1
# 50 2024-04-25  20:00  Premier League  Matchweek 29  Thu  Away      W   4   0
# 51 2024-04-28  16:30  Premier League  Matchweek 35  Sun  Away      W   2   0
# 52 2024-05-04  17:30  Premier League  Matchweek 36  Sat  Home      W   5   1
# 53 2024-05-11  12:30  Premier League  Matchweek 37  Sat  Away      W   4   0
# 54 2024-05-14  20:00  Premier League  Matchweek 34  Tue  Away      W   2   0
# 55 2024-05-19  16:00  Premier League  Matchweek 38  Sun  Home      W   3   1
#
#            Opponent  ...  day_code  target  GF_rolling  GA_rolling Sh_rolling  \
# 5            Fulham  ...         5       1    2.000000    0.333333  20.000000
# 6          West Ham  ...         5       1    2.666667    0.666667  16.333333
# 8   Nott'ham Forest  ...         5       1    3.333333    1.000000  21.333333
# 10           Wolves  ...         5       0    3.333333    0.666667  14.000000
# 12          Arsenal  ...         6       0    2.000000    1.000000  19.666667
# 13         Brighton  ...         5       1    1.000000    1.000000  11.333333
# 15   Manchester Utd  ...         6       1    1.000000    1.333333  12.333333
# 16      Bournemouth  ...         5       1    1.666667    0.666667  11.333333
# 18          Chelsea  ...         6       0    3.666667    0.666667  17.000000
# 19        Liverpool  ...         5       0    4.333333    1.666667  18.333333
# 21        Tottenham  ...         6       0    3.666667    2.000000  17.000000
# 22      Aston Villa  ...         2       0    2.666667    2.666667  15.666667
# 23       Luton Town  ...         6       1    1.333333    1.666667  11.666667
# 25   Crystal Palace  ...         5       0    1.666667    1.666667  12.333333
# 26          Everton  ...         2       1    1.333333    1.333333  13.000000
# 27    Sheffield Utd  ...         5       1    2.333333    1.333333  19.666667
# 29    Newcastle Utd  ...         5       1    2.333333    1.000000  19.666667
# 31          Burnley  ...         2       1    2.666667    1.000000  22.333333
# 32        Brentford  ...         0       1    2.666667    1.000000  19.666667
# 33          Everton  ...         5       1    3.000000    1.333333  22.000000
# 35          Chelsea  ...         5       0    2.666667    0.666667  19.333333
# 36        Brentford  ...         1       1    2.000000    0.666667  25.000000
# 37      Bournemouth  ...         5       1    1.333333    0.333333  25.000000
# 39   Manchester Utd  ...         6       1    1.000000    0.333333  23.666667
# 41        Liverpool  ...         6       0    1.666667    0.333333  22.333333
# 43          Arsenal  ...         6       0    1.666667    0.666667  17.333333
# 44      Aston Villa  ...         2       1    1.333333    0.666667  16.333333
# 45   Crystal Palace  ...         5       1    1.666667    0.666667  15.666667
# 47       Luton Town  ...         5       1    2.666667    1.000000  18.333333
# 50         Brighton  ...         3       1    4.333333    1.333333  26.333333
# 51  Nott'ham Forest  ...         6       1    4.333333    1.000000  22.666667
# 52           Wolves  ...         5       1    3.666667    0.333333  20.333333
# 53           Fulham  ...         5       1    3.666667    0.333333  14.333333
# 54        Tottenham  ...         1       1    3.666667    0.333333  14.666667
# 55         West Ham  ...         6       1    3.666667    0.333333  13.333333
#
#    SoT_rolling Dist_rolling FK_rolling  PK_rolling  PKatt_rolling
# 5     7.000000    16.366667   0.666667    0.000000       0.333333
# 6     5.666667    16.666667   0.666667    0.333333       0.666667
# 8     8.666667    16.166667   1.000000    0.333333       0.666667
# 10    7.000000    16.133333   1.000000    0.333333       0.333333
# 12    8.333333    17.633333   1.333333    0.000000       0.000000
# 13    4.000000    17.133333   1.000000    0.000000       0.000000
# 15    4.333333    17.666667   0.666667    0.000000       0.000000
# 16    4.666667    16.966667   1.000000    0.333333       0.333333
# 18    7.333333    17.466667   1.000000    0.333333       0.333333
# 19    8.666667    16.733333   1.000000    0.666667       0.666667
# 21    7.333333    16.433333   0.666667    0.333333       0.333333
# 22    6.000000    15.433333   0.666667    0.333333       0.333333
# 23    3.666667    12.366667   0.333333    0.000000       0.000000
# 25    4.000000    13.166667   0.333333    0.000000       0.000000
# 26    5.666667    14.766667   0.333333    0.000000       0.000000
# 27    7.666667    18.800000   0.666667    0.333333       0.333333
# 29    7.000000    18.366667   0.333333    0.333333       0.333333
# 31    7.666667    18.733333   1.000000    0.333333       0.333333
# 32    6.333333    17.500000   1.000000    0.000000       0.000000
# 33   10.000000    18.100000   1.000000    0.000000       0.000000
# 35    7.333333    17.466667   0.333333    0.000000       0.000000
# 36    7.666667    17.500000   0.333333    0.000000       0.000000
# 37    6.000000    16.966667   0.333333    0.000000       0.000000
# 39    7.000000    16.333333   0.666667    0.000000       0.000000
# 41    8.000000    16.933333   0.666667    0.000000       0.000000
# 43    6.666667    17.266667   0.666667    0.000000       0.000000
# 44    5.000000    16.833333   0.333333    0.000000       0.000000
# 45    6.000000    16.233333   0.666667    0.000000       0.000000
# 47    6.666667    15.400000   0.666667    0.000000       0.000000
# 50   10.333333    16.300000   0.666667    0.333333       0.333333
# 51    8.666667    16.666667   0.333333    0.333333       0.333333
# 52    7.666667    17.533333   0.666667    0.333333       0.333333
# 53    7.000000    17.000000   0.666667    0.666667       0.666667
# 54    7.666667    17.200000   0.333333    1.000000       1.000000
# 55    7.333333    15.800000   0.000000    1.333333       1.333333
#
# [35 rows x 40 columns]

# %%
matches_rolling = matches.groupby("Team").apply(lambda x: rolling_averages(x, cols, new_cols))
matches_rolling
# Out:
#                                 Date   Time            Comp         Round  \
# Team
# Arsenal                4  2023-09-03  16:30  Premier League   Matchweek 4
#                        5  2023-09-17  16:30  Premier League   Matchweek 5
#                        7  2023-09-24  14:00  Premier League   Matchweek 6
#                        9  2023-09-30  15:00  Premier League   Matchweek 7
#                        11 2023-10-08  16:30  Premier League   Matchweek 8
# ...                              ...    ...             ...           ...
# WolverhamptonWanderers 40 2024-04-24  19:45  Premier League  Matchweek 29
#                        41 2024-04-27  15:00  Premier League  Matchweek 35
#                        42 2024-05-04  17:30  Premier League  Matchweek 36
#                        43 2024-05-11  15:00  Premier League  Matchweek 37
#                        44 2024-05-19  16:00  Premier League  Matchweek 38
#
#                            Day Venue Result  GF  GA         Opponent  ...  \
# Team                                                                  ...
# Arsenal                4   Sun  Home      W   3   1   Manchester Utd  ...
#                        5   Sun  Away      W   1   0          Everton  ...
#                        7   Sun  Home      D   2   2        Tottenham  ...
#                        9   Sat  Away      W   4   0      Bournemouth  ...
#                        11  Sun  Home      W   1   0  Manchester City  ...
# ...                        ...   ...    ...  ..  ..              ...  ...
# WolverhamptonWanderers 40  Wed  Home      L   0   1      Bournemouth  ...
#                        41  Sat  Home      W   2   1       Luton Town  ...
#                        42  Sat  Away      L   1   5  Manchester City  ...
#                        43  Sat  Home      L   1   3   Crystal Palace  ...
#                        44  Sun  Away      L   0   2        Liverpool  ...
#
#                            day_code  target  GF_rolling  GA_rolling  \
# Team
# Arsenal                4          6       1    1.666667    1.000000
#                        5          6       1    2.000000    1.000000
#                        7          6       0    2.000000    1.000000
#                        9          5       1    2.000000    1.000000
#                        11         6       1    2.333333    0.666667
# ...                             ...     ...         ...         ...
# WolverhamptonWanderers 40         2       0    1.000000    2.000000
#                        41         5       1    0.666667    1.666667
#                        42         5       0    0.666667    1.333333
#                        43         5       0    1.000000    2.333333
#                        44         6       0    1.333333    3.000000
#
#                           Sh_rolling SoT_rolling Dist_rolling FK_rolling  \
# Team
# Arsenal                4   15.333333    6.000000    16.433333   0.000000
#                        5   16.000000    5.333333    15.066667   0.000000
#                        7   16.000000    6.000000    15.400000   0.000000
#                        9   14.000000    4.333333    16.433333   0.000000
#                        11  12.666667    4.666667    16.600000   0.000000
# ...                              ...         ...          ...        ...
# WolverhamptonWanderers 40   9.666667    4.000000    20.533333   0.333333
#                        41  10.333333    3.333333    18.766667   0.000000
#                        42  11.000000    4.000000    19.666667   0.000000
#                        43  10.000000    3.333333    15.966667   0.000000
#                        44   9.666667    4.666667    14.133333   0.000000
#
#                            PK_rolling  PKatt_rolling
# Team
# Arsenal                4     0.666667       0.666667
#                        5     0.666667       0.666667
#                        7     0.333333       0.333333
#                        9     0.333333       0.333333
#                        11    1.000000       1.000000
# ...                               ...            ...
# WolverhamptonWanderers 40    0.333333       0.333333
#                        41    0.000000       0.000000
#                        42    0.000000       0.000000
#                        43    0.000000       0.000000
#                        44    0.000000       0.000000
#
# [700 rows x 40 columns]

# %%
matches_rolling = matches_rolling.droplevel('Team')

# %%
matches_rolling
# Out:
#          Date   Time            Comp         Round  Day Venue Result  GF  GA  \
# 4  2023-09-03  16:30  Premier League   Matchweek 4  Sun  Home      W   3   1
# 5  2023-09-17  16:30  Premier League   Matchweek 5  Sun  Away      W   1   0
# 7  2023-09-24  14:00  Premier League   Matchweek 6  Sun  Home      D   2   2
# 9  2023-09-30  15:00  Premier League   Matchweek 7  Sat  Away      W   4   0
# 11 2023-10-08  16:30  Premier League   Matchweek 8  Sun  Home      W   1   0
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 40 2024-04-24  19:45  Premier League  Matchweek 29  Wed  Home      L   0   1
# 41 2024-04-27  15:00  Premier League  Matchweek 35  Sat  Home      W   2   1
# 42 2024-05-04  17:30  Premier League  Matchweek 36  Sat  Away      L   1   5
# 43 2024-05-11  15:00  Premier League  Matchweek 37  Sat  Home      L   1   3
# 44 2024-05-19  16:00  Premier League  Matchweek 38  Sun  Away      L   0   2
#
#            Opponent  ...  day_code  target  GF_rolling  GA_rolling Sh_rolling  \
# 4    Manchester Utd  ...         6       1    1.666667    1.000000  15.333333
# 5           Everton  ...         6       1    2.000000    1.000000  16.000000
# 7         Tottenham  ...         6       0    2.000000    1.000000  16.000000
# 9       Bournemouth  ...         5       1    2.000000    1.000000  14.000000
# 11  Manchester City  ...         6       1    2.333333    0.666667  12.666667
# ..              ...  ...       ...     ...         ...         ...        ...
# 40      Bournemouth  ...         2       0    1.000000    2.000000   9.666667
# 41       Luton Town  ...         5       1    0.666667    1.666667  10.333333
# 42  Manchester City  ...         5       0    0.666667    1.333333  11.000000
# 43   Crystal Palace  ...         5       0    1.000000    2.333333  10.000000
# 44        Liverpool  ...         6       0    1.333333    3.000000   9.666667
#
#    SoT_rolling Dist_rolling FK_rolling  PK_rolling  PKatt_rolling
# 4     6.000000    16.433333   0.000000    0.666667       0.666667
# 5     5.333333    15.066667   0.000000    0.666667       0.666667
# 7     6.000000    15.400000   0.000000    0.333333       0.333333
# 9     4.333333    16.433333   0.000000    0.333333       0.333333
# 11    4.666667    16.600000   0.000000    1.000000       1.000000
# ..         ...          ...        ...         ...            ...
# 40    4.000000    20.533333   0.333333    0.333333       0.333333
# 41    3.333333    18.766667   0.000000    0.000000       0.000000
# 42    4.000000    19.666667   0.000000    0.000000       0.000000
# 43    3.333333    15.966667   0.000000    0.000000       0.000000
# 44    4.666667    14.133333   0.000000    0.000000       0.000000
#
# [700 rows x 40 columns]

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
matches_rolling
# Out:
#           Date   Time            Comp         Round  Day Venue Result  GF  GA  \
# 0   2023-09-03  16:30  Premier League   Matchweek 4  Sun  Home      W   3   1
# 1   2023-09-17  16:30  Premier League   Matchweek 5  Sun  Away      W   1   0
# 2   2023-09-24  14:00  Premier League   Matchweek 6  Sun  Home      D   2   2
# 3   2023-09-30  15:00  Premier League   Matchweek 7  Sat  Away      W   4   0
# 4   2023-10-08  16:30  Premier League   Matchweek 8  Sun  Home      W   1   0
# ..         ...    ...             ...           ...  ...   ...    ...  ..  ..
# 695 2024-04-24  19:45  Premier League  Matchweek 29  Wed  Home      L   0   1
# 696 2024-04-27  15:00  Premier League  Matchweek 35  Sat  Home      W   2   1
# 697 2024-05-04  17:30  Premier League  Matchweek 36  Sat  Away      L   1   5
# 698 2024-05-11  15:00  Premier League  Matchweek 37  Sat  Home      L   1   3
# 699 2024-05-19  16:00  Premier League  Matchweek 38  Sun  Away      L   0   2
#
#             Opponent  ...  day_code  target  GF_rolling  GA_rolling  \
# 0     Manchester Utd  ...         6       1    1.666667    1.000000
# 1            Everton  ...         6       1    2.000000    1.000000
# 2          Tottenham  ...         6       0    2.000000    1.000000
# 3        Bournemouth  ...         5       1    2.000000    1.000000
# 4    Manchester City  ...         6       1    2.333333    0.666667
# ..               ...  ...       ...     ...         ...         ...
# 695      Bournemouth  ...         2       0    1.000000    2.000000
# 696       Luton Town  ...         5       1    0.666667    1.666667
# 697  Manchester City  ...         5       0    0.666667    1.333333
# 698   Crystal Palace  ...         5       0    1.000000    2.333333
# 699        Liverpool  ...         6       0    1.333333    3.000000
#
#     Sh_rolling SoT_rolling Dist_rolling FK_rolling  PK_rolling  PKatt_rolling
# 0    15.333333    6.000000    16.433333   0.000000    0.666667       0.666667
# 1    16.000000    5.333333    15.066667   0.000000    0.666667       0.666667
# 2    16.000000    6.000000    15.400000   0.000000    0.333333       0.333333
# 3    14.000000    4.333333    16.433333   0.000000    0.333333       0.333333
# 4    12.666667    4.666667    16.600000   0.000000    1.000000       1.000000
# ..         ...         ...          ...        ...         ...            ...
# 695   9.666667    4.000000    20.533333   0.333333    0.333333       0.333333
# 696  10.333333    3.333333    18.766667   0.000000    0.000000       0.000000
# 697  11.000000    4.000000    19.666667   0.000000    0.000000       0.000000
# 698  10.000000    3.333333    15.966667   0.000000    0.000000       0.000000
# 699   9.666667    4.666667    14.133333   0.000000    0.000000       0.000000
#
# [700 rows x 40 columns]

# %% [markdown]
# # Retaining machine learning model

# %%
def make_predictions(data, predictors):
    train = data[data["Date"] < '2024-01-01']
    test = data[data["Date"] > '2024-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual = test["target"], predicted = preds), index = test.index)
    precision = precision_score(test["target"], preds)
    return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.528

# %%
combined
# Out:
#      actual  predicted
# 17        1          0
# 18        1          1
# 19        1          1
# 20        1          0
# 21        1          1
# ..      ...        ...
# 695       0          0
# 696       1          0
# 697       0          0
# 698       0          0
# 699       0          0
#
# [366 rows x 2 columns]

# %%
combined = combined.merge(matches_rolling[["Date", "Team", "Opponent", "Result"]], left_index = True, right_index = True)

# %%
combined
# Out:
#      actual  predicted       Date                    Team         Opponent  \
# 17        1          0 2024-01-20                 Arsenal   Crystal Palace
# 18        1          1 2024-01-30                 Arsenal  Nott'ham Forest
# 19        1          1 2024-02-04                 Arsenal        Liverpool
# 20        1          0 2024-02-11                 Arsenal         West Ham
# 21        1          1 2024-02-17                 Arsenal          Burnley
# ..      ...        ...        ...                     ...              ...
# 695       0          0 2024-04-24  WolverhamptonWanderers      Bournemouth
# 696       1          0 2024-04-27  WolverhamptonWanderers       Luton Town
# 697       0          0 2024-05-04  WolverhamptonWanderers  Manchester City
# 698       0          0 2024-05-11  WolverhamptonWanderers   Crystal Palace
# 699       0          0 2024-05-19  WolverhamptonWanderers        Liverpool
#
#     Result
# 17       W
# 18       W
# 19       W
# 20       W
# 21       W
# ..     ...
# 695      L
# 696      W
# 697      L
# 698      L
# 699      L
#
# [366 rows x 6 columns]

# %% [markdown]
# # Combining home and away predictions

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {
    "BrightonandHoveAlbion": "Brighton",
    "ManchesterUnited": "Manchester Utd",
    "NewcastleUnited": "Newcastle",
    "TottenhamHotspur": "Tottenham",
    "WestHamUnited": "West Ham",
    "WolverhamptonWanderers": "Wolves"
}
mapping = MissingDict(**map_values)

# %%
mapping["WestHamUnited"]
# Out:
# 'West Ham'

# %%
combined["new_team"] = combined["Team"].map(mapping)

# %%
combined
# Out:
#      actual  predicted       Date                    Team         Opponent  \
# 17        1          0 2024-01-20                 Arsenal   Crystal Palace
# 18        1          1 2024-01-30                 Arsenal  Nott'ham Forest
# 19        1          1 2024-02-04                 Arsenal        Liverpool
# 20        1          0 2024-02-11                 Arsenal         West Ham
# 21        1          1 2024-02-17                 Arsenal          Burnley
# ..      ...        ...        ...                     ...              ...
# 695       0          0 2024-04-24  WolverhamptonWanderers      Bournemouth
# 696       1          0 2024-04-27  WolverhamptonWanderers       Luton Town
# 697       0          0 2024-05-04  WolverhamptonWanderers  Manchester City
# 698       0          0 2024-05-11  WolverhamptonWanderers   Crystal Palace
# 699       0          0 2024-05-19  WolverhamptonWanderers        Liverpool
#
#     Result new_team
# 17       W  Arsenal
# 18       W  Arsenal
# 19       W  Arsenal
# 20       W  Arsenal
# 21       W  Arsenal
# ..     ...      ...
# 695      L   Wolves
# 696      W   Wolves
# 697      L   Wolves
# 698      L   Wolves
# 699      L   Wolves
#
# [366 rows x 7 columns]

# %%
merged = combined.merge(combined, left_on = ["Date", "new_team"], right_on = ["Date", "Opponent"])
merged
# Out:
#      actual_x  predicted_x       Date                  Team_x  \
# 0           1            0 2024-01-20                 Arsenal
# 1           1            1 2024-01-30                 Arsenal
# 2           1            1 2024-02-04                 Arsenal
# 3           1            0 2024-02-11                 Arsenal
# 4           1            1 2024-02-17                 Arsenal
# ..        ...          ...        ...                     ...
# 233         0            0 2024-04-24  WolverhamptonWanderers
# 234         1            0 2024-04-27  WolverhamptonWanderers
# 235         0            0 2024-05-04  WolverhamptonWanderers
# 236         0            0 2024-05-11  WolverhamptonWanderers
# 237         0            0 2024-05-19  WolverhamptonWanderers
#
#           Opponent_x Result_x new_team_x  actual_y  predicted_y  \
# 0     Crystal Palace        W    Arsenal         0            0
# 1    Nott'ham Forest        W    Arsenal         0            0
# 2          Liverpool        W    Arsenal         0            0
# 3           West Ham        W    Arsenal         0            0
# 4            Burnley        W    Arsenal         0            0
# ..               ...      ...        ...       ...          ...
# 233      Bournemouth        L     Wolves         1            0
# 234       Luton Town        W     Wolves         0            0
# 235  Manchester City        L     Wolves         1            1
# 236   Crystal Palace        L     Wolves         1            0
# 237        Liverpool        L     Wolves         1            0
#
#                Team_y Opponent_y Result_y        new_team_y
# 0       CrystalPalace    Arsenal        L     CrystalPalace
# 1    NottinghamForest    Arsenal        L  NottinghamForest
# 2           Liverpool    Arsenal        L         Liverpool
# 3       WestHamUnited    Arsenal        L          West Ham
# 4             Burnley    Arsenal        L           Burnley
# ..                ...        ...      ...               ...
# 233       Bournemouth     Wolves        W       Bournemouth
# 234         LutonTown     Wolves        L         LutonTown
# 235    ManchesterCity     Wolves        W    ManchesterCity
# 236     CrystalPalace     Wolves        W     CrystalPalace
# 237         Liverpool     Wolves        W         Liverpool
#
# [238 rows x 13 columns]

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] == 0)]["actual_x"].value_counts()
# Out:
# 1    40
# 0    31
# Name: actual_x, dtype: int64

# %%
27 / 40
# Out:
# 0.675

# %%
#generating our pickle file
with open('model.pkl', 'wb') as file:
    pickle.dump(rf, file)
